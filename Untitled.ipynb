# %%
import pickle 

with open("xgb.pkl", "rb") as f:
    loaded_model = pickle.load(f)
print("Model loaded sucessfully")
# Out:
# Model loaded sucessfully

# %%
# # Import the XGBoost library first
# import xgboost as xgb

# # Now you can use xgb
# # For example:
# model = xgb.XGBClassifier()
